# %%
import sys
import os
sys.path.append(os.path.join(os.getcwd(), "..", "..", "..", "..", ".."))
sys.path.append(os.path.join(os.getcwd(), "..", "..", "..", ".."))
sys.path.append(os.path.join(os.getcwd(), "..", "..", ".."))
sys.path.append(os.path.join(os.getcwd(), "..", ".."))
sys.path
# Out:
# ['/home/blessyantony/dev/git/zoonosis/src/jupyter_notebooks/results-analysis/coronaviridae',
#  '/opt/conda/lib/python38.zip',
#  '/opt/conda/lib/python3.8',
#  '/opt/conda/lib/python3.8/lib-dynload',
#  '',
#  '/home/blessyantony/.local/lib/python3.8/site-packages',
#  '/opt/conda/lib/python3.8/site-packages',
#  '/opt/conda/lib/python3.8/site-packages/IPython/extensions',
#  '/home/blessyantony/.ipython',
#  '/home/blessyantony/dev/git/zoonosis/src/jupyter_notebooks/results-analysis/coronaviridae/../../../../..',
#  '/home/blessyantony/dev/git/zoonosis/src/jupyter_notebooks/results-analysis/coronaviridae/../../../..',
#  '/home/blessyantony/dev/git/zoonosis/src/jupyter_notebooks/results-analysis/coronaviridae/../../..',
#  '/home/blessyantony/dev/git/zoonosis/src/jupyter_notebooks/results-analysis/coronaviridae/../..']

# %%
import pandas as pd
import os
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path

from src.utils import utils, evaluation_utils, visualization_utils
from sklearn.metrics import auc, precision_recall_curve
from statistics import mean

# %%
file_paths = {
    "msl128vs30_s64_UA": os.path.join(os.getcwd(), "..","..", "..", "..", "output/raw/coronaviridae_s_prot_variants/20240808/sars-cov-2/uniprot/cov-S-multi-transfer_learning_mlm_hybrid_attn_fnn_2l_lr1e-4/msl128vs30_s64/tl_tf_multi_sarscov2_variants_s.csv"),
    "msl128vs30cls_s64_UA": os.path.join(os.getcwd(), "..","..", "..", "..", "output/raw/coronaviridae_s_prot_variants/20240808/sars-cov-2/uniprot/cov-S-multi-transfer_learning_mlm_hybrid_attn_fnn_2l_lr1e-4/msl128vs30cls_s64/tl_tf_multi_sarscov2_variants_s.csv"),
    "msl256vs30_s64_UA": os.path.join(os.getcwd(), "..","..", "..", "..", "output/raw/coronaviridae_s_prot_variants/20240808/sars-cov-2/uniprot/cov-S-multi-transfer_learning_mlm_hybrid_attn_fnn_2l_lr1e-4/msl256vs30_s64/tl_tf_multi_sarscov2_variants_s.csv"),
    "msl256vs30cls_s64_UA": os.path.join(os.getcwd(), "..","..", "..", "..", "output/raw/coronaviridae_s_prot_variants/20240808/sars-cov-2/uniprot/cov-S-multi-transfer_learning_mlm_hybrid_attn_fnn_2l_lr1e-4/msl256vs30cls_s64/tl_tf_multi_sarscov2_variants_s.csv")
}

# %%
dfs = []
for k, v in file_paths.items():
    df = pd.read_csv(v)
    df["model"] = k
    df["id"] = df["id"].str.extract(r"\['(.+)'\]")
    index_seq_pred = df[df["id"] == "WIV04"]["Human"].values[0]
    df["Human_pred_diff"] = df["Human"] - index_seq_pred
    dfs.append(df)
df = pd.concat(dfs)
df
# Out:
#          Cat    Cattle       Chicken  Dromedary camel  Gray wolf     Human  \
# 0   0.006134  0.573490  6.467954e-04         0.074003   0.055859  0.021283
# 1   0.023987  0.535671  1.181538e-03         0.102456   0.036526  0.097806
# 2   0.008477  0.599940  7.195822e-04         0.080849   0.040363  0.033643
# 3   0.087980  0.195794  1.084544e-03         0.109114   0.011576  0.529405
# 4   0.088668  0.196143  1.133529e-03         0.109758   0.011875  0.526386
# ..       ...       ...           ...              ...        ...       ...
# 13  0.049596  0.000008  5.709027e-07         0.012002   0.000761  0.934219
# 14  0.044830  0.000010  7.142315e-07         0.015068   0.000796  0.935710
# 15  0.053220  0.000008  6.498222e-07         0.011768   0.000830  0.930592
# 16  0.215357  0.000038  5.505472e-06         0.003451   0.006076  0.772485
# 17  0.021125  0.003011  1.828231e-04         0.251469   0.006929  0.708347
#
#          Pig           Yak          id y_true                 model  \
# 0   0.014702  2.538816e-01  QQM19141.1  Human     msl128vs30_s64_UA
# 1   0.015414  1.869586e-01  UZG29433.1  Human     msl128vs30_s64_UA
# 2   0.010577  2.254315e-01  QTJ90974.1  Human     msl128vs30_s64_UA
# 3   0.013246  5.180073e-02  UPP14409.1  Human     msl128vs30_s64_UA
# 4   0.013587  5.244939e-02  UWM38596.1  Human     msl128vs30_s64_UA
# ..       ...           ...         ...    ...                   ...
# 13  0.003413  9.274993e-07  QRF70806.1  Human  msl256vs30cls_s64_UA
# 14  0.003584  1.224536e-06  QRN78347.1  Human  msl256vs30cls_s64_UA
# 15  0.003580  1.036695e-06  QWE88920.1  Human  msl256vs30cls_s64_UA
# 16  0.002578  8.980142e-06  QRX49325.1  Human  msl256vs30cls_s64_UA
# 17  0.008300  6.359647e-04  UOZ45804.1  Human  msl256vs30cls_s64_UA
#
#     Human_pred_diff
# 0         -0.006921
# 1          0.069602
# 2          0.005440
# 3          0.501201
# 4          0.498182
# ..              ...
# 13         0.163530
# 14         0.165022
# 15         0.159904
# 16         0.001797
# 17        -0.062341
#
# [72 rows x 12 columns]

# %%
df
# Out:
#          Cat    Cattle       Chicken  Dromedary camel  Gray wolf     Human  \
# 0   0.006134  0.573490  6.467954e-04         0.074003   0.055859  0.021283
# 1   0.023987  0.535671  1.181538e-03         0.102456   0.036526  0.097806
# 2   0.008477  0.599940  7.195822e-04         0.080849   0.040363  0.033643
# 3   0.087980  0.195794  1.084544e-03         0.109114   0.011576  0.529405
# 4   0.088668  0.196143  1.133529e-03         0.109758   0.011875  0.526386
# ..       ...       ...           ...              ...        ...       ...
# 13  0.049596  0.000008  5.709027e-07         0.012002   0.000761  0.934219
# 14  0.044830  0.000010  7.142315e-07         0.015068   0.000796  0.935710
# 15  0.053220  0.000008  6.498222e-07         0.011768   0.000830  0.930592
# 16  0.215357  0.000038  5.505472e-06         0.003451   0.006076  0.772485
# 17  0.021125  0.003011  1.828231e-04         0.251469   0.006929  0.708347
#
#          Pig           Yak          id y_true                 model  \
# 0   0.014702  2.538816e-01  QQM19141.1  Human     msl128vs30_s64_UA
# 1   0.015414  1.869586e-01  UZG29433.1  Human     msl128vs30_s64_UA
# 2   0.010577  2.254315e-01  QTJ90974.1  Human     msl128vs30_s64_UA
# 3   0.013246  5.180073e-02  UPP14409.1  Human     msl128vs30_s64_UA
# 4   0.013587  5.244939e-02  UWM38596.1  Human     msl128vs30_s64_UA
# ..       ...           ...         ...    ...                   ...
# 13  0.003413  9.274993e-07  QRF70806.1  Human  msl256vs30cls_s64_UA
# 14  0.003584  1.224536e-06  QRN78347.1  Human  msl256vs30cls_s64_UA
# 15  0.003580  1.036695e-06  QWE88920.1  Human  msl256vs30cls_s64_UA
# 16  0.002578  8.980142e-06  QRX49325.1  Human  msl256vs30cls_s64_UA
# 17  0.008300  6.359647e-04  UOZ45804.1  Human  msl256vs30cls_s64_UA
#
#     Human_pred_diff
# 0         -0.006921
# 1          0.069602
# 2          0.005440
# 3          0.501201
# 4          0.498182
# ..              ...
# 13         0.163530
# 14         0.165022
# 15         0.159904
# 16         0.001797
# 17        -0.062341
#
# [72 rows x 12 columns]

# %%
mapping_df = pd.read_csv(os.path.join(os.getcwd(), "..","..", "..", "..", "input/data/coronaviridae/20240313/wiv04/SARS_CoV_2_Variants_ViralZone.csv"))

# %%
mapping_df = mapping_df[~mapping_df["seq"].isna()]
mapping_df
# Out:
#        pango_lineage who_name                 tag      emergence_location  \
# 0               BA.1  Omicron  Variant of Concern            South Africa
# 1               BA.2  Omicron  Variant of Concern            South Africa
# 2          BA.2.12.1  Omicron  Variant of Concern           North-America
# 3            BA.2.75  Omicron  Variant of Concern                   India
# 4               JN.1  Omicron  Variant of Concern              Luxembourg
# 5               BA.4  Omicron  Variant of Concern            South Africa
# 6               BA.5  Omicron  Variant of Concern            South Africa
# 7             BQ.1.1  Omicron  Variant of Concern                 Nigeria
# 8             EG.5.1  Omicron  Variant of Concern  Indonesia/France/China
# 9            XBB.1.5  Omicron  Variant of Concern                     USA
# 12           B.1.1.7    Alpha      Other variants                      UK
# 18           B.1.351     Beta      Other variants            South Africa
# 19         B.1.617.2    Delta      Other variants                   India
# 20  B.1.427, B.1.429  Epsilon      Other variants                     USA
# 21           B.1.525      Eta      Other variants                     NaN
# 22        B.1.1.28.1    Gamma      Other variants                  Brazil
# 23           B.1.526     Iota      Other variants                     USA
# 24         B.1.617.1    Kappa      Other variants                   India
# 25       B.1.1.1.C37   Lambda      Other variants                    Peru
# 27        B.1.1.28.2     Zeta      Other variants                  Brazil
#
#    emergence_date                                    spike_mutations  \
# 0          Dec-21  A67V, H69-, V70-, T95I, G142D, V143-, Y144-, Y...
# 1          Dec-21  T19I, L24-, P25-, P26-, A27S, G142D, V213G, G3...
# 2          Dec-21  T19I, L24-, P25-, P26-, A27S, G142D, V213G, G3...
# 3          Jun-22  T19I, L24-, P25-, P26-, A27S, G142D, K147E, W1...
# 4          Jan-23  A27S, A264D, A570V, D405N, D614G, D796Y, E484K...
# 5          Jan-22  T19I, L24-, P25-, P26-, A27S, H69-, V70-, V213...
# 6          Jan-22  T19I, L24-, P25-, P26-, A27S, H69-, V70-, V213...
# 7          Jul-22  T19I, L24-, P25-, P26-, A27S, H69-, V70-, V213...
# 8          Jan-23  A27S, D405N, D614G, D796Y, E484A, F456L, F486P...
# 9          Nov-22  A27S, A475V, D405N, D614G, D796Y, E484A, F456L...
# 12         Sep-20  H69-, V70-, Y144-, N501Y, A570D, D614G, P681H,...
# 18         Aug-20     D80A, D215G, K417N, E484K, N501Y, D614G, A701V
# 19         Dec-20  T19R, 156-, 157-, R158G, L452R, T478K, D614G, ...
# 20         Sep-20                          S13I, W152C, L452R, D614G
# 21         Dec-20  A67V, H69-, V70-, Y144-, E484K, D614G, Q677H, ...
# 22         Jul-20  L18F, T20N, P26S, D138Y, R190S, K417T, E484K, ...
# 23         Nov-20                                 T95I, D253G, D614G
# 24         Oct-21   G142D, E154K, L452R, E484Q, D614G, P681R, Q1071H
# 25         Dec-20             G75V, T76I, L452Q, F490S, D614G, T859N
# 27         Oct-20                               E484K, D614G, V1176F
#
#            seq virus_host_name
# 0   UFO69279.1    Homo sapiens
# 1   OM371884.1    Homo sapiens
# 2   OM958567.1    Homo sapiens
# 3   ON990685.1    Homo sapiens
# 4   WRK13149.1    Homo sapiens
# 5   UPP14409.1    Homo sapiens
# 6   UOZ45804.1    Homo sapiens
# 7   UWM38596.1    Homo sapiens
# 8   WGM84363.1    Homo sapiens
# 9   UZG29433.1    Homo sapiens
# 12  QWE88920.1             NaN
# 18  QRN78347.1             NaN
# 19  QUD52764.1             NaN
# 20  QQM19141.1             NaN
# 21  QRF70806.1             NaN
# 22  QRX39425.1             NaN
# 23  QRX49325.1             NaN
# 24  QTY83052.1             NaN
# 25  QTJ90974.1             NaN
# 27  QQX30509.1             NaN

# %%
df = df.merge(mapping_df[["seq", "pango_lineage"]], how="left", left_on="id", right_on="seq")

# %%
df[df["id"] == "WIV04"]
# Out:
#          Cat    Cattle   Chicken  Dromedary camel  Gray wolf     Human  \
# 12  0.007064  0.605889  0.000613         0.076271   0.040858  0.028204
# 18  0.417219  0.000354  0.000942         0.012350   0.004716  0.462348
# 51  0.232556  0.000010  0.003878         0.004051   0.000138  0.739641
# 59  0.217691  0.000035  0.000005         0.003171   0.006038  0.770689
#
#          Pig           Yak     id y_true                 model  \
# 12  0.010321  2.307809e-01  WIV04  Human     msl128vs30_s64_UA
# 18  0.101991  7.917170e-05  WIV04  Human  msl128vs30cls_s64_UA
# 51  0.019725  6.522137e-07  WIV04  Human     msl256vs30_s64_UA
# 59  0.002363  8.323927e-06  WIV04  Human  msl256vs30cls_s64_UA
#
#     Human_pred_diff  seq pango_lineage
# 12              0.0  NaN           NaN
# 18              0.0  NaN           NaN
# 51              0.0  NaN           NaN
# 59              0.0  NaN           NaN

# %%
plt.clf()
plt.figure(figsize=(10, 12))
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 20
plt.rcParams.update({'font.size': 20})

colors = sns.color_palette('tab10')
models = list(df["model"].unique())

color_palette_dict = {k: v for k, v in zip(models, colors)}

ax = sns.barplot(df[~df["seq"].isna()], y="pango_lineage", x="Human", hue="model")
               # boxprops={"facecolor": (.3, .5, .7, .5)})
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

for model, color in zip(models, colors):
    ax.axvline(df[(df["model"] == model) & (df["id"] == "WIV04")]["Human"].values[0], color=color, linestyle="--")

plt.show()
