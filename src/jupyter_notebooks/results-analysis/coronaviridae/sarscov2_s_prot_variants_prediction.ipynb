# %%
import sys
import os
sys.path.append(os.path.join(os.getcwd(), "..", "..", "..", "..", ".."))
sys.path.append(os.path.join(os.getcwd(), "..", "..", "..", ".."))
sys.path.append(os.path.join(os.getcwd(), "..", "..", ".."))
sys.path.append(os.path.join(os.getcwd(), "..", ".."))
sys.path
# Out:
# ['/home/blessyantony/dev/git/zoonosis/src/jupyter_notebooks/results-analysis/coronaviridae',
#  '/opt/conda/lib/python38.zip',
#  '/opt/conda/lib/python3.8',
#  '/opt/conda/lib/python3.8/lib-dynload',
#  '',
#  '/home/blessyantony/.local/lib/python3.8/site-packages',
#  '/opt/conda/lib/python3.8/site-packages',
#  '/opt/conda/lib/python3.8/site-packages/IPython/extensions',
#  '/home/blessyantony/.ipython',
#  '/home/blessyantony/dev/git/zoonosis/src/jupyter_notebooks/results-analysis/coronaviridae/../../../../..',
#  '/home/blessyantony/dev/git/zoonosis/src/jupyter_notebooks/results-analysis/coronaviridae/../../../..',
#  '/home/blessyantony/dev/git/zoonosis/src/jupyter_notebooks/results-analysis/coronaviridae/../../..',
#  '/home/blessyantony/dev/git/zoonosis/src/jupyter_notebooks/results-analysis/coronaviridae/../..',
#  '/home/blessyantony/dev/git/zoonosis/src/jupyter_notebooks/results-analysis/coronaviridae/../../../../..',
# ...

# %%
import pandas as pd
import os
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path

from src.utils import utils, evaluation_utils, visualization_utils
from sklearn.metrics import auc, precision_recall_curve
from statistics import mean

# %%
file_path = os.path.join(os.getcwd(), "..","..", "..", "..", "output/raw/coronaviridae_s_prot_variants/20240801/sars-cov-2/uniprot/cov-S-multi-transfer_learning_mlm_hybrid_attn_fnn_2l_lr1e-4/aligned_msl128_s64_vs30/tl_tf_multi_sarscov2_variants_s_aligned_independent_with_label.csv")

# %%
df = pd.read_csv(file_path)
df
# Out:
#          Cat    Cattle       Chicken  Dromedary camel  Gray wolf     Human  \
# 0   0.135320  0.000003  4.785529e-07         0.008954   0.001875  0.853358
# 1   0.132933  0.000003  4.696077e-07         0.009004   0.001825  0.855755
# 2   0.132543  0.000003  4.755876e-07         0.009073   0.001826  0.856073
# 3   0.074618  0.000011  2.277486e-06         0.025773   0.001497  0.897381
# 4   0.133723  0.000003  4.971383e-07         0.009162   0.001868  0.854751
# 5   0.093262  0.000011  2.387598e-06         0.021819   0.001921  0.882171
# 6   0.125789  0.000003  4.857421e-07         0.009482   0.001722  0.862531
# 7   0.132639  0.000003  4.713955e-07         0.009040   0.001824  0.856014
# 8   0.136721  0.000002  4.489129e-07         0.008673   0.001865  0.852260
# 9   0.091896  0.000010  2.161409e-06         0.021339   0.001844  0.884136
# 10  0.137575  0.000003  4.673956e-07         0.008773   0.001902  0.851259
# ...

# %%
df["id"] = df["id"].str.extract(r"\['(.+)'\]")

# %%
df
# Out:
#          Cat    Cattle       Chicken  Dromedary camel  Gray wolf     Human  \
# 0   0.135320  0.000003  4.785529e-07         0.008954   0.001875  0.853358
# 1   0.132933  0.000003  4.696077e-07         0.009004   0.001825  0.855755
# 2   0.132543  0.000003  4.755876e-07         0.009073   0.001826  0.856073
# 3   0.074618  0.000011  2.277486e-06         0.025773   0.001497  0.897381
# 4   0.133723  0.000003  4.971383e-07         0.009162   0.001868  0.854751
# 5   0.093262  0.000011  2.387598e-06         0.021819   0.001921  0.882171
# 6   0.125789  0.000003  4.857421e-07         0.009482   0.001722  0.862531
# 7   0.132639  0.000003  4.713955e-07         0.009040   0.001824  0.856014
# 8   0.136721  0.000002  4.489129e-07         0.008673   0.001865  0.852260
# 9   0.091896  0.000010  2.161409e-06         0.021339   0.001844  0.884136
# 10  0.137575  0.000003  4.673956e-07         0.008773   0.001902  0.851259
# ...

# %%
index_seq_pred = df[df["id"] == "WIV04"]["Human"].values[0]

# %%
df["Human_pred_diff"] = df["Human"] - index_seq_pred

# %%
df
# Out:
#          Cat    Cattle       Chicken  Dromedary camel  Gray wolf     Human  \
# 0   0.135320  0.000003  4.785529e-07         0.008954   0.001875  0.853358
# 1   0.132933  0.000003  4.696077e-07         0.009004   0.001825  0.855755
# 2   0.132543  0.000003  4.755876e-07         0.009073   0.001826  0.856073
# 3   0.074618  0.000011  2.277486e-06         0.025773   0.001497  0.897381
# 4   0.133723  0.000003  4.971383e-07         0.009162   0.001868  0.854751
# 5   0.093262  0.000011  2.387598e-06         0.021819   0.001921  0.882171
# 6   0.125789  0.000003  4.857421e-07         0.009482   0.001722  0.862531
# 7   0.132639  0.000003  4.713955e-07         0.009040   0.001824  0.856014
# 8   0.136721  0.000002  4.489129e-07         0.008673   0.001865  0.852260
# 9   0.091896  0.000010  2.161409e-06         0.021339   0.001844  0.884136
# 10  0.137575  0.000003  4.673956e-07         0.008773   0.001902  0.851259
# ...
